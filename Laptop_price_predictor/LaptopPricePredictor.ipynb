# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Mansi\Desktop\Laptop_price_predictor\laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df = df.drop(["Unnamed: 0"], axis = 1)

# %%
df["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %% [markdown]
# Price Data is skewed , with lots of laptop in range of 0-80000

# %% [markdown]
# ### **Data Preprocessing**

# %%
df["Ram"] = df["Ram"].str.replace("GB","")
df["Weight"] = df["Weight"].str.replace("kg", "", case = False)

# %%
df["Ram"] = df["Ram"].astype(int)
df["Weight"] = df["Weight"].astype(float)

# %% [markdown]
# ## **EDA**

# %%
plt.figure(figsize = (5,3))
df["Company"].value_counts().plot(kind = "bar", color = "brown")
# Out:
# <Axes: xlabel='Company'>

# %%
plt.figure(figsize = (15,8))
plt.subplot(221)
sns.histplot(df["Inches"], kde = True, bins = 10, color = "#452659")

plt.subplot(222)
sns.histplot(df["Ram"], kde = True, bins = 5, color = "#3c2947")

plt.subplot(223)
sns.barplot(df["OpSys"], color = "#3c2947")

plt.subplot(224)
sns.histplot(df["Price"], kde = True, color = "#452659")
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
#  **Finding Average price for each brand**

# %% [markdown]
# There is avariation in prices with each company, that is brands have a impact on prices

# %%
plt.figure(figsize = (5,3))
df.groupby("Company")["Price"].mean().plot(kind = "bar")
plt.ylabel("Average Price")
plt.xlabel("Company")
plt.show()

# %%
plt.figure(figsize = (5,3))
df["TypeName"].value_counts().plot(kind = "bar")
plt.xticks(rotation = 45)
plt.title("Counts of each type of laptop")
# Out:
# Text(0.5, 1.0, 'Counts of each type of laptop')

# %%
plt.figure(figsize = (5,3))
sns.barplot(df, x = df["TypeName"], y = df["Price"], hue = "TypeName")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Workstation laptops are the most expensive. So, type also has a effect on price

# %%
plt.figure(figsize = (5,3))
df.groupby("Ram")["Price"].mean().plot(kind = "bar")
plt.xticks(rotation = 0)
plt.title("Ram(in GB) vs Price")
plt.xlabel("RAM (in GBs)")
# Out:
# Text(0.5, 0, 'RAM (in GBs)')

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(df, x = df["Inches"], y = df["Price"], hue = "TypeName")
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %% [markdown]
# There is no clear relationship between these two features, there is a weak correlation.

# %%
df["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# This feature consists of touchscreen and IPS display

# %%
## extracting those
df["Touchscreen"] = df["ScreenResolution"].apply(lambda x: 1 if "Touchscreen" in x else 0)

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches             ScreenResolution  \
# 22       HP   Notebook    15.6                     1366x768
# 264    Dell   Notebook    15.6            Full HD 1920x1080
# 915  Lenovo   Notebook    13.3            Full HD 1920x1080
# 170  Huawei  Ultrabook    13.0  IPS Panel Full HD 2160x1440
# 930  Lenovo   Notebook    15.6                     1366x768
#
#                                       Cpu  Ram     Memory  \
# 22           AMD E-Series E2-9000e 1.5GHz    4  500GB HDD
# 264            Intel Core i5 7200U 2.5GHz    8    1TB HDD
# 915            Intel Core i5 7200U 2.5GHz    4  128GB SSD
# 170            Intel Core i5 7200U 2.5GHz    8  256GB SSD
# 930  Intel Pentium Quad Core N4200 1.1GHz    4    1TB HDD
#
#                        Gpu       OpSys  Weight     Price  Touchscreen
# 22           AMD Radeon R2       No OS    1.86  13746.24            0
# 264     AMD Radeon R5 M430  Windows 10    2.24  30103.20            0
# ...

# %%
df[df["Touchscreen"] == 1][["Touchscreen"]].value_counts()
# Out:
# Touchscreen
# 1              192
# Name: count, dtype: int64

# %%
sns.barplot(x = df["Touchscreen"], y = df["Price"])   # Touchscreens are expensive
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
# finding ips panel
df["IPS_panel"] = df["ScreenResolution"].apply(lambda x: 1 if "IPS Panel" in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches   ScreenResolution  \
# 1172    Asus            Notebook    15.6           1366x768
# 953     Asus  2 in 1 Convertible    12.5  Full HD 1920x1080
# 276     Dell            Notebook    17.3  Full HD 1920x1080
# 118     Asus            Notebook    17.3  Full HD 1920x1080
# 583     Dell            Notebook    15.6  Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 1172  Intel Celeron Dual Core N3050 1.6GHz    4             500GB HDD
# 953            Intel Core M M7-6Y75 1.2GHz    8    64GB Flash Storage
# 276             Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
# 118               Intel Core i3 6006U 2GHz    4               1TB HDD
# 583             Intel Core i7 7600U 2.8GHz   16             256GB SSD
#
#                         Gpu       OpSys  Weight       Price  Touchscreen  \
# 1172      Intel HD Graphics  Windows 10    2.20  19660.3200            0
# ...

# %%
df["IPS_panel"].value_counts()
# Out:
# IPS_panel
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,3))
sns.barplot(x = df["IPS_panel"], y = df["Price"])
plt.title("Price Variation")
# Out:
# Text(0.5, 1.0, 'Price Variation')

# %% [markdown]
# Laptop with IPS panel have more average price

# %%
## extracting resolution
new = df["ScreenResolution"].str.split("x", n=1, expand = True)

# %%
new.head()
# Out:
#                                0     1
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df["X_res"] = new[0]

# %%
df["Y_res"] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df["X_res"] = df["X_res"].str.replace(",","").str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df["X_res"] = df["X_res"].astype(int)

# %%
df["Y_res"] = df["Y_res"].astype(int)

# %%
numeric = df.select_dtypes(include = "number")

# %%
numeric.corr()["Price"]
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS_panel      0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %% [markdown]
# Prices have a strong correlation with resolution.

# %% [markdown]
# #### **Creating a column Ppi**

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df["PPI"] = (((df["X_res"]**2 + df["Y_res"]**2))**0.5/df["Inches"]).astype(float)

# %% [markdown]
# PPI has a very strong correlation with Price column

# %% [markdown]
# #### **Cpu categories**

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df["Cpu_name"] = df["Cpu"].apply(lambda x: " ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
def fetch_processor(text):
  if text == "Intel Core i7" or text == "Intel Core i5" or text == "Intel Core i3":
    return text
  else:
    if text.split()[0] == "Intel":
      return "Other Intel Processor"
    else:
      return "AMD Processor"

# %%
df["Cpu_brand"] = df["Cpu_name"].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df["Cpu_brand"].value_counts()
# Out:
# Cpu_brand
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,3))
sns.barplot(df, x = df["Cpu_brand"], y=df["Price"], hue = "Cpu_brand")
plt.xticks(rotation = 45)
plt.show()

# %%
import pandas as pd

df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

# 1. Assign split values and clean whitespace
df["first"] = new[0].astype(str).str.strip()
# Handle missing second values safely without using inplace=True
df["second"] = new[1].astype(str).str.strip() if len(new) > 1 else "0"
df["second"] = df["second"].fillna("0")

# 2. Extract features from the first memory slot
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# 3. Extract features from the second memory slot
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# 4. Strip out ALL non-numeric characters (Crucial Fix: regex=True)
df["first"] = df["first"].str.replace(r"\D", "", regex=True)
df["second"] = df["second"].str.replace(r"\D", "", regex=True)

# Handle any empty strings resulting from rows that had no numbers
df["first"] = df["first"].replace("", "0")
df["second"] = df["second"].replace("", "0")

# 5. Convert to integers safely
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

# 6. Calculate total capacities per storage type
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

# %%
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram             Memory  \
# 0        Intel Core i5 2.3GHz    8            128 SSD
# 1        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3        Intel Core i7 2.7GHz   16            512 SSD
# 4        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight  ...  IPS_panel  X_res  Y_res  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  ...          1   2560   1600
# 1        Intel HD Graphics 6000  macOS    1.34  ...          0   1440    900
# ...

# %%
num = df.select_dtypes(include = "number")

# %%
num.corr()["Price"]
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS_panel        0.252208
# X_res            0.556529
# Y_res            0.552809
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns = ["Hybrid","Flash_Storage"], inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram             Memory  \
# 0        Intel Core i5 2.3GHz    8            128 SSD
# 1        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3        Intel Core i7 2.7GHz   16            512 SSD
# 4        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %% [markdown]
# #### **GPU column**

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df["Gpu_brand"]=df["Gpu"].apply(lambda x: x.split()[0])

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df["Gpu_brand"] != "ARM"]

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
df.drop(columns = ["Gpu"], inplace = True)

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(df, x=df["OpSys"], y=df["Price"], hue = "OpSys")
plt.xticks(rotation = 45)
plt.show()

# %%
def cat_os(inp):
  if inp == "Windows 10" or inp == "Windows 7" or inp == "Windows 10 S":
    return "Windows"
  elif inp == "macOS" or inp == "Mac OS X":
    return "Mac"
  else:
    return "Others/no OS/Linux"

# %%
df["os"] = df["OpSys"].apply(cat_os)

# %%
df = df.drop("OpSys", axis = 1)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Weight', 'Price', 'Touchscreen', 'IPS_panel', 'X_res',
#        'Y_res', 'PPI', 'Cpu_name', 'Cpu_brand', 'HDD', 'SSD', 'Gpu_brand',
#        'os'],
#       dtype='object')

# %%
plt.figure(figsize=(5,3))
sns.barplot(df,x=df["os"], y=df["Price"], hue="os")
plt.xticks(rotation = 0)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.distplot(df["Weight"])
plt.show()
# Out:
# C:\Users\Mansi\AppData\Local\Temp\ipykernel_11844\608420091.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Weight"])

# %% [markdown]
# This is bimodal.

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x=df["Weight"],y=df["Price"])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %% [markdown]
# There is a weak relationship between Weight and price

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram             Memory  Weight        Price  \
# 0        Intel Core i5 2.3GHz    8            128 SSD    1.37   71378.6832
# 1        Intel Core i5 1.8GHz    8  128 Flash Storage    1.34   47895.5232
# 2  Intel Core i5 7200U 2.5GHz    8            256 SSD    1.86   30636.0000
# 3        Intel Core i7 2.7GHz   16            512 SSD    1.83  135195.3360
# 4        Intel Core i5 3.1GHz    8            256 SSD    1.37   96095.8080
#
#    Touchscreen  IPS_panel  X_res  Y_res         PPI       Cpu_name  \
# ...

# %%
numeric = df.select_dtypes(include = "number")
sns.heatmap(numeric.corr())
# Out:
# <Axes: >

# %% [markdown]
# Now, we know that target column is skewed and this could create problems so we will have to apply some transformations to make it normal
# A skewed target column may result into a very high MAE.

# %%
df["Price"].skew()
# Out:
# np.float64(1.5197503994318975)

# %%
sns.distplot(np.log (df["Price"]))
# Out:
# C:\Users\Mansi\AppData\Local\Temp\ipykernel_11844\2689144226.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log (df["Price"]))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns = ["Price", "X_res", "Y_res", "ScreenResolution", "Cpu", "Memory", "Inches","Cpu_name"])
y = np.log(df["Price"])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS_panel  \
# 0      Apple           Ultrabook    8    1.37            0          1
# 1      Apple           Ultrabook    8    1.34            0          0
# 2         HP            Notebook    8    1.86            0          0
# 3      Apple           Ultrabook   16    1.83            0          1
# 4      Apple           Ultrabook    8    1.37            0          1
# ...      ...                 ...  ...     ...          ...        ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1          1
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1          1
# 1300  Lenovo            Notebook    2    1.50            0          0
# 1301      HP            Notebook    6    2.19            0          0
# 1302    Asus            Notebook    4    2.20            0          0
#
#              PPI              Cpu_brand   HDD  SSD Gpu_brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.15, random_state = 2)

# %% [markdown]
# #### **One Hot Encoding for Categorical Columns**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
step1 = ColumnTransformer(transformers = [
    ("col tnf", OneHotEncoder(sparse_output = False, drop = "first"), [0,1,7,10,11])
], remainder = "passthrough")
step2 = LinearRegression()

pipe = Pipeline([
    ("step1", step1),
    ("step2", step2)
])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print("r2_score", r2_score(y_test, y_pred))
print("MAE", mean_absolute_error(y_test,y_pred))
print("MSE ", mean_squared_error(y_test,y_pred))
# Out:
# r2_score 0.8073277450155159
# MAE 0.21017827953018972
# MSE  0.07370698688393562

# %% [markdown]
# Since we transformed the target to a normal distribution (using a log transformation), the target values and the resulting prediction errors are now very small (mostly between 0 and 1).This creates a mathematical phenomenon where MSE becomes smaller than MAE, which directly answers why MSE dropped down to 0.0737 while your MAE is 0.2101.
#
# We can also observe that the error is very less that it is between 0 and 1 , squaring that number will give even more smaller number hence MSE< MAE, moreover, we must say that out model is performing very well its predictions are accurate that is why yi-yi^ is almost 0.

# %% [markdown]
# #### **Ridge Regression**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.812733103373946
# MAE 0.20926802210371445

# %% [markdown]
# #### **Lasso Regression**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853947620582
# MAE 0.21114361575113452

# %% [markdown]
# #### **KNN**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8030481878603557
# MAE 0.19266635529773937

# %% [markdown]
# **Finding optimal k value**

# %%
k_values = np.arange(1,11)
mae = []
for i in k_values:
  pipe.set_params(step2__n_neighbors=i)
  pipe.fit(X_train,y_train)
  y_pred = pipe.predict(X_test)
  mae.append(mean_absolute_error(y_test,y_pred))
mae
# Out:
# [0.2061942842602119,
#  0.20524652661558326,
#  0.19266635529773937,
#  0.1986426894847764,
#  0.20013885517594093,
#  0.20784563533873276,
#  0.20768424350761647,
#  0.2117551217343571,
#  0.2161667113882546,
#  0.21782473472062192]

# %%
plt.figure(figsize = (5,3))
sns.lineplot(x=k_values, y=mae)
# Out:
# <Axes: >

# %% [markdown]
# We can see that there is minimum MAE score for K=3, hence 3 is the optimal values

# %% [markdown]
# #### **Decision Tree**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8413099955531737
# MAE 0.18091552278153172

# %% [markdown]
# **SVM**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8083168388456576
# MAE 0.20239400567756663

# %% [markdown]
# **Random Forest**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %% [markdown]
# **ExtraTrees**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15,
                              bootstrap=True)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8850720167552375
# MAE 0.16154538000217084

# %% [markdown]
# **Adaboost**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7882487031710141
# MAE 0.23090426402272068

# %% [markdown]
# **Gradient Boost**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8836219370688932
# MAE 0.15899430973228282

# %% [markdown]
# **XGboost**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8771404806375557
# MAE 0.16262936288951352

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **Voting Regressor**

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15, bootstrap=True)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10, bootstrap=True)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8893367282142649
# MAE 0.15870584813809469

# %% [markdown]
# **Stacking**

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8788245181634435
# MAE 0.1661272150706424

# %% [markdown]
# **Exporting the model**

# %%
import pickle

# %%
pickle.dump(df, open("df.pkl", "wb"))
pickle.dump(pipe, open("pipe.pkl", "wb"))
#
